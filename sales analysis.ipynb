# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Amazon Sales data.csv', parse_dates=['Order Date', 'Ship Date'])
df
# Out:
#                                Region                Country        Item Type
# 0               Australia and Oceania                 Tuvalu        Baby Food  \
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.describe()
# Out:
#                 Order Date      Order ID            Ship Date   Units Sold
# count                  100  1.000000e+02                  100   100.000000  \
# mean   2013-09-16 14:09:36  5.550204e+08  2013-10-09 22:48:00  5128.710000
# min    2010-02-02 00:00:00  1.146066e+08  2010-02-25 00:00:00   124.000000
# 25%    2012-02-14 12:00:00  3.389225e+08  2012-02-24 18:00:00  2836.250000
# 50%    2013-07-12 12:00:00  5.577086e+08  2013-08-11 12:00:00  5382.500000
# 75%    2015-04-07 00:00:00  7.907551e+08  2015-04-28 00:00:00  7369.000000
# max    2017-05-22 00:00:00  9.940222e+08  2017-06-17 00:00:00  9925.000000
# std                    NaN  2.606153e+08                  NaN  2794.484562
#
#        Unit Price   Unit Cost  Total Revenue    Total Cost  Total Profit
# count  100.000000  100.000000   1.000000e+02  1.000000e+02  1.000000e+02
# mean   276.761300  191.048000   1.373488e+06  9.318057e+05  4.416820e+05
# min      9.330000    6.920000   4.870260e+03  3.612240e+03  1.258020e+03
# ...

# %%
df.nunique()
# Out:
# Region              7
# Country            76
# Item Type          12
# Sales Channel       2
# Order Priority      4
# Order Date        100
# Order ID          100
# Ship Date          99
# Units Sold         99
# Unit Price         12
# Unit Cost          12
# Total Revenue     100
# Total Cost        100
# Total Profit      100
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue
# Order ID       1.000000   -0.222907   -0.190941  -0.213201      -0.314688  \
# Units Sold    -0.222907    1.000000   -0.070486  -0.092232       0.447784
# Unit Price    -0.190941   -0.070486    1.000000   0.987270       0.752360
# Unit Cost     -0.213201   -0.092232    0.987270   1.000000       0.715623
# Total Revenue -0.314688    0.447784    0.752360   0.715623       1.000000
# Total Cost    -0.328944    0.374746    0.787905   0.774895       0.983928
# Total Profit  -0.234638    0.564550    0.557365   0.467214       0.897327
#
#                Total Cost  Total Profit
# Order ID        -0.328944     -0.234638
# Units Sold       0.374746      0.564550
# Unit Price       0.787905      0.557365
# Unit Cost        0.774895      0.467214
# Total Revenue    0.983928      0.897327
# Total Cost       1.000000      0.804091
# Total Profit     0.804091      1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
new_df = pd.get_dummies(df.loc[:, ['Region', 'Item Type']], columns=['Region', 'Item Type'])

# %%
new_df['Sales Channel'] = le.fit_transform(df['Sales Channel'])

# %%
df['Order Date'][0].year
# Out:
# 2010

# %%
new_df['Order Year'] = df['Order Date'].apply(lambda x: x.year)
new_df['Ship Year'] = df['Ship Date'].apply(lambda x: x.year)

# %%
new_df[['Units Sold', 'Unit Price','Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']] = df[['Units Sold', 'Unit Price','Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']]

# %%
new_df
# Out:
#     Region_Asia  Region_Australia and Oceania
# 0         False                          True  \
# 1         False                         False
# 2         False                         False
# 3         False                         False
# 4         False                         False
# ..          ...                           ...
# 95        False                         False
# 96         True                         False
# 97        False                         False
# 98        False                         False
# 99        False                         False
#
#     Region_Central America and the Caribbean  Region_Europe
# 0                                      False          False  \
# 1                                       True          False
# 2                                      False           True
# 3                                      False          False
# 4                                      False          False
# ...

# %%
abs(new_df.corr(numeric_only=True)['Total Profit']).sort_values(ascending=False)
# Out:
# Total Profit                                1.000000
# Total Revenue                               0.897327
# Total Cost                                  0.804091
# Item Type_Cosmetics                         0.600656
# Units Sold                                  0.564550
# Unit Price                                  0.557365
# Unit Cost                                   0.467214
# Item Type_Fruits                            0.328209
# Item Type_Household                         0.275278
# Item Type_Personal Care                     0.244167
# Item Type_Beverages                         0.223475
# Region_Sub-Saharan Africa                   0.177487
# Item Type_Vegetables                        0.133585
# Sales Channel                               0.130019
# Region_Middle East and North Africa         0.102701
# Region_Asia                                 0.091949
# Item Type_Snacks                            0.076995
# Region_Europe                               0.075570
# ...
